# %% [markdown]
# # Course Outline
# -- --
#
# [Course practical information](#Course-practical-information)
#
# [About W3C and the Web](#About-W3C-and-the-Web)
#
# [Tools for editing and browsing](#Tools-for-editin-and-browsing)
#
# [Week 1: My first Web page in HTML5](#Week-1:-My-first-Web-page-in-HTML5)
#
# [Week 2: Attributes, images and links](#Week-2:- Attributes-images-and-links)
#
# [Week 3: Adding style with CSS](#Week-3:-Adding-style-with-CSS)
#
# [Week 4: Fixing and debugging](#Week-4:-Fixing-and-debugging)
#
# [Week 5: More HTML5 and CSS](#Week-5:-More-HTML5-and-CSS)
#
# [Week 6: Basics of page Layout](#Week-6:-Basics-of-page-Layout)
#
# -- --
#
# ### Course practical information
#
# - Getting around the course
# - Course syllabus
# - Grading and due Dates
#
# -- --
#
# ### About W3C and the Web
#
# - Why accessibility is Important
# - Why internationalization is important
# - W3C tools
#
# -- --
#
# ### Tools for editing and browsing
#
# - HTML editors
# - Web browsers
#
# -- --
#
# ### Week 1: My first Web page in HTML5
#
# 1.1 Introduction to Week 1
# 1.2 The big three: HTML5, CSS3 and JavaScript
# 1.3 Elements, tags and attributes
# 1.4 Character encoding
# 1.5 Best practices
# 1.6 More on tags
# 1.7 Exercises - Week 1
#
# -- --
#
# ### Week 2: Attributes, images and links
#
# 2.1 Introduction to Week 2
# 2.2 Attributes
# 2.3 Semantic meaning
# 2.4 Images
# 2.5 Hyperlinks
# 2.4 Exercises - Week 2
#
# -- --
#
# ### Week 3: Adding style with CSS
#
# 3.1 Introduction to Week 3
# 3.2 CSS basic syntax
# 3.3 CSS properties
# 3.4 Lists and selectors
# 3.5 Exercises - Week 3
#
# -- --
#
# ### Week 4: Fixing and debugging
#
# 4.1 Introduction to Week 4
# 4.2 Tools
# 4.3 Debugging and the CSS box model
# 4.4 Debugging CSS precedence
# 4.5 Exercises - Week 4
#
# -- --
#
# ### Week 5: More HTML5 and CSS
#
# 5.1 Introduction to Week 5
# 5.2 Tables
# 5.3 Multimedia
# 5.4 Embedding content (OPTIONAL)
# 5.5 CSS tricks
# 5.6 Exercises - Week 5
#
# -- --
#
# ### Week 6: Basics of page Layout
#
# 6.1 Introduction to Week 6
# 6.2 Page layout concepts
# 6.3 Flexbox
# 6.4 More flexbox  (OPTIONAL)
# 6.5 Recipe project
# 6.6 Where to from here?
# 6.7 Final exam
#
# -- --
#
# Course Evaluation
