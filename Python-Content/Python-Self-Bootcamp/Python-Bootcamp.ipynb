# %% [markdown]
# ## [Table of Contents](#TOC)
#
# [1. Introduction](#Introduction)
#
# + [Curriculum Overview](#Curriculum-Overview)
#
#
# + [Python 2 Vs Python 3](#Pyhton-2-Vs-Python-3)
#
#
# + [How to Approach this Course](#How-to-approach-this-course)
#
# -- --
#
# [2. Tool Box](#Tool-)
#
# + [Python Installation](#Python-installation)
#
#
# + [Environment Selection](#Env-Selection)
#
#
# + [Jupyter Notebooks](#Jupyter-notebooks)
#
#
# + [Additional Learning Resources](#Additional-learning-resources)
#
#
# + [Git and Github Overview](#Git-n-Github-overview)
#
# -- --
#
# [3. Object & Data Structures Basics](#Objects-n-Data-structures-basics)
#
# + [Numbers](#Numbers)
#
#
# + [Strings](#Strings)
#
#
# + [Lists](#Lists)
#
#
# + [Dictionaries](#Dictionaries)
#
#
# + [Tuples](#Tuples)
#
#
# + [Files](#Files)
#
#
# + [Sets](#Sets)
#
#
# + [Booleans](#Booleans)
#
# -- --
#
# [4. Comparison Operators](#Comparison-Ops)
#
#
# + [Basic Operators](#Basic-Ops)
#
#
# + [Chained Comparison Operators](#Chained-comparison-Ops)
#
# -- --
#
# [5. Python Statements](#Python Statements)
#
# + [If, elif and else](#If-elif-else)
#
#
# + [For Loops](#For-loops)
#
#
# + [While Loops](#While-Loops)
#
#
# + [Range Function](#Range-functions)
#
#
# + [List Comprehensions](#List-comprehensions)
#
#
# -- --
#
#
# [6. Methods and Functions](#Methods-n-Functions)
#
#
# + [Methods](#Methods)
#
# + [Functions](#Functions)
#
# + [Lambda Expressions](#Lambda-expressions)
#
# + [Nested Statements](#Nested-statements)
#
# + [Scope](#Scope)
#
# -- --
#
# [8. First Milestone Project](#First-milestone -project)
#
# + [Simple Arcade Game](#Simple-arcade-game)
#
#
# [9. Object Oriented Programming & Design](#OOP-n-D)
#
#
# + [Objects](#Objects)
#
#
# + [Classes](#Classes)
#
#
# + [Methods](#Methods)
#
#
# + [Inheritence](#Inheritence)
#
#
# + [Special Methods](#Special-methods)
#
#
# -- --
#
# [10. Errors & Exception Handling](#Errors-n-exception-handling)
#
# + [Errors](#Errors)
#
#
# + [Exceptions](#Exceptions)
#
#     - [Try](#Try)
#
#     - [Except](#Except)
#
#     - [Finally](#Finally)
#
# -- --
#
# [11. Second Milestone Project](#Second-milestone-project)
#
# + [Creating a 2D Platformer](#Creating-2D-platformer)
#
# -- --
#
#
# [12. Modules and Packages](#Modules-n-packages)
#
#
# + [Creating Modules](#Creating-modules)
#
#
# + [#Installing Modules](#Installing-modules)
#
#
# + [Exploring the Python Ecosystem](#Exploring-python-ecosys)
#
# -- --
#
# [13. Built in Functions](#Built-in-functions)
#
# + [Map](#map)
#
#
# + [Reduce](#reduce)
#
#
# + [Filter](#filter)
#
#
# + [Zip](#zip)
#
#
# + [Enumerate](#enumerate)
#
#
# + [All and Any](#all-n-any)
#
#
# + [Complex](#complex)
#
#
# -- --
#
#
# [14. Decorators in Python](#Decorators)
#
# + [Part 1](#Part-1)
#
# + [Part 2](#Part-2)
#
# + [Part 3](#Part-3)
#
#
# -- --
#
# [15. Python Generators](#Generators)
#
# + [Iteraton Vs Gneration](#Interation-Vs-Generation)
#
#
# + [Creating Generators](#Creating-Generators)
#
#
# -- --
#
# [Final Capstone Project](#Final-Capstone)
#
#
# + [Complex 2D Platfomer with A.I](#Complex-2D-with-A.I)
#
# -- --
#
# [Leveling Up](#Leveling-Up)
#
# + [Data Structures](#Data Structures)
#
#
# + [Algorithms](#Algorithms)
#
#
# + [Full Stack Development](#Full-stack-development)
#
#    - [Flask](#Flask)
#
#    - [Django](#Django)
#
#    - [Djangular](#Djangular)
#
# -- --
#
# **Go to: **[TOC](#Table-of-Contents)
